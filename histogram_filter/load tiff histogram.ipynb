# %% [markdown]
# # load tiff histogram
#
# [opencv python doc link](https://docs.opencv.org/3.1.0/d1/db7/tutorial_py_histogram_begins.html)

# %%
import os
import cv2
import tensorflow as tf
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
image_filepath = '/code/research/stain/python_image_histogram_filter/input_dir/239_9/HE'
image_filename = 'tile_x043_y048.tiff'

# %%
img = cv2.imread(os.path.join(image_filepath, image_filename))

# %%
# cv2.imshow('image',img)

# %%
plt.imshow(img)
plt.show()

# %%
   color = ('b','g','r')
   for i,col in enumerate(color):
       histr = cv2.calcHist([img],[i],None,[256],[0,256])
       plt.plot(histr,color = col)
       plt.xlim([0,256])
   plt.show()
